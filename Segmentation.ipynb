# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from glob import glob
import os
import cv2
import numpy as np
import cv2

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, concatenate, BatchNormalization, Dropout, Lambda , Activation, Conv2DTranspose
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
os.environ['PYTHONHASHSEED'] = '42'
np.random.seed(42)
tf.random.set_seed(42)

# %%
batch_size =6
learning_rate = 1e-4
epochs = 100
height = 240
width = 320

# %%
dataset_path = os.path.join('/content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels')
files_dir = os.path.join('/content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files')

# %%
model_file = os.path.join(files_dir, 'unet-non-aug.h5')
log_file = os.path.join(files_dir, 'unet-non-aug.csv')

# %%
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
create_dir(files_dir)

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Dropout(0.3)(x)

    return x

# %%
def encoder_block(input, num_filters):
    x = conv_block(input, num_filters)
    p = MaxPooling2D((2, 2))(x)
    return x, p

# %%
def decoder_block(input, skip_connection, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input)
    x = concatenate([x, skip_connection], axis=3)
    x = conv_block(x, num_filters)
    return x

# %%
def build_unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# %%
def load_data(path):
    train_x = sorted(glob(os.path.join(path, "Segmentation_Data/*")))[:-5]
    train_y = sorted(glob(os.path.join(path, "Masks/*")))[:-5]

    val_x = sorted(glob(os.path.join(path, "Segmentation_Data/*")))[-5:]
    val_y = sorted(glob(os.path.join(path, "Masks/*")))[-5:]
    return (train_x, train_y), (val_x, val_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = x / 255.0
    return x.astype(np.float32)

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = x / 255.0
    x = np.expand_dims(x, axis=-1)
    return x.astype(np.float32)

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y
    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([height, width, 3])
    y.set_shape([height, width, 1])

    return x, y

# %%
def tf_dataset(x, y, batch=6):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

(train_x, train_y), (val_x, val_y) = load_data(dataset_path)

# %%
(train_x, train_y), (val_x, val_y) = load_data(dataset_path)

# %%
print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Val: {len(val_x)} - {len(val_y)}")
# Out:
# Train: 18 - 18
# Val: 5 - 5

# %%
def random_flip(x, y):
    flip_left_right = tf.random.uniform(shape=[], minval=0, maxval=1, dtype=tf.float32)
    flip_up_down = tf.random.uniform(shape=[], minval=0, maxval=1, dtype=tf.float32)

    x = tf.cond(flip_left_right > 0.5, lambda: tf.image.flip_left_right(x), lambda: x)
    y = tf.cond(flip_left_right > 0.5, lambda: tf.image.flip_left_right(y), lambda: y)

    x = tf.cond(flip_up_down > 0.5, lambda: tf.image.flip_up_down(x), lambda: x)
    y = tf.cond(flip_up_down > 0.5, lambda: tf.image.flip_up_down(y), lambda: y)

    return x, y

# %%
def tf_dataset(x, y, batch=6, augment=False):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.map(tf_parse, num_parallel_calls=tf.data.AUTOTUNE)
    if augment:
        dataset = dataset.map(lambda x, y: random_flip(x, y), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    return dataset

(train_x, train_y), (val_x, val_y) = load_data(dataset_path)

train_dataset = tf_dataset(train_x, train_y, batch=batch_size, augment=True)
val_dataset = tf_dataset(val_x, val_y, batch=batch_size, augment=True)

# %%
callbacks = [
    ModelCheckpoint(model_file, verbose=1, save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10),
    CSVLogger(log_file),
]

# %%
model = build_unet(input_shape=(height, width, 3))

model.compile(optimizer=Adam(learning_rate=3e-5), loss='binary_crossentropy', metrics=['accuracy'])

model.fit(
    train_dataset,
    epochs=500,
    validation_data=val_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/500
# 3/3 [==============================] - ETA: 0s - loss: 0.9749 - accuracy: 0.2682
# Epoch 1: val_loss improved from inf to 0.70908, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 23s 6s/step - loss: 0.9749 - accuracy: 0.2682 - val_loss: 0.7091 - val_accuracy: 0.0598 - lr: 3.0000e-05
# Epoch 2/500
# 3/3 [==============================] - ETA: 0s - loss: 0.9248 - accuracy: 0.3114
# Epoch 2: val_loss improved from 0.70908 to 0.70778, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.9248 - accuracy: 0.3114 - val_loss: 0.7078 - val_accuracy: 0.0597 - lr: 3.0000e-05
# Epoch 3/500
# 3/3 [==============================] - ETA: 0s - loss: 0.8819 - accuracy: 0.3627
# Epoch 3: val_loss improved from 0.70778 to 0.70604, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.8819 - accuracy: 0.3627 - val_loss: 0.7060 - val_accuracy: 0.0603 - lr: 3.0000e-05
# Epoch 4/500
# 3/3 [==============================] - ETA: 0s - loss: 0.8461 - accuracy: 0.4117
# Epoch 4: val_loss improved from 0.70604 to 0.70401, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.8461 - accuracy: 0.4117 - val_loss: 0.7040 - val_accuracy: 0.0615 - lr: 3.0000e-05
# Epoch 5/500
# 3/3 [==============================] - ETA: 0s - loss: 0.8102 - accuracy: 0.4577
# Epoch 5: val_loss improved from 0.70401 to 0.70346, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.8102 - accuracy: 0.4577 - val_loss: 0.7035 - val_accuracy: 0.0647 - lr: 3.0000e-05
# Epoch 6/500
# 3/3 [==============================] - ETA: 0s - loss: 0.7758 - accuracy: 0.4994
# Epoch 6: val_loss did not improve from 0.70346
# 3/3 [==============================] - 3s 701ms/step - loss: 0.7758 - accuracy: 0.4994 - val_loss: 0.7047 - val_accuracy: 0.0717 - lr: 3.0000e-05
# Epoch 7/500
# 3/3 [==============================] - ETA: 0s - loss: 0.7414 - accuracy: 0.5396
# Epoch 7: val_loss did not improve from 0.70346
# 3/3 [==============================] - 2s 772ms/step - loss: 0.7414 - accuracy: 0.5396 - val_loss: 0.7051 - val_accuracy: 0.0815 - lr: 3.0000e-05
# Epoch 8/500
# 3/3 [==============================] - ETA: 0s - loss: 0.7073 - accuracy: 0.5807
# Epoch 8: val_loss did not improve from 0.70346
# 3/3 [==============================] - 2s 768ms/step - loss: 0.7073 - accuracy: 0.5807 - val_loss: 0.7045 - val_accuracy: 0.1114 - lr: 3.0000e-05
# Epoch 9/500
# 3/3 [==============================] - ETA: 0s - loss: 0.6746 - accuracy: 0.6222
# Epoch 9: val_loss improved from 0.70346 to 0.70322, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.6746 - accuracy: 0.6222 - val_loss: 0.7032 - val_accuracy: 0.1201 - lr: 3.0000e-05
# Epoch 10/500
# 3/3 [==============================] - ETA: 0s - loss: 0.6430 - accuracy: 0.6674
# Epoch 10: val_loss improved from 0.70322 to 0.70137, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.6430 - accuracy: 0.6674 - val_loss: 0.7014 - val_accuracy: 0.1246 - lr: 3.0000e-05
# Epoch 11/500
# 3/3 [==============================] - ETA: 0s - loss: 0.6124 - accuracy: 0.7119
# Epoch 11: val_loss improved from 0.70137 to 0.69907, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.6124 - accuracy: 0.7119 - val_loss: 0.6991 - val_accuracy: 0.1728 - lr: 3.0000e-05
# Epoch 12/500
# 3/3 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.7549
# Epoch 12: val_loss improved from 0.69907 to 0.69599, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.5829 - accuracy: 0.7549 - val_loss: 0.6960 - val_accuracy: 0.3351 - lr: 3.0000e-05
# Epoch 13/500
# 3/3 [==============================] - ETA: 0s - loss: 0.5536 - accuracy: 0.7946
# Epoch 13: val_loss improved from 0.69599 to 0.69218, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.5536 - accuracy: 0.7946 - val_loss: 0.6922 - val_accuracy: 0.5643 - lr: 3.0000e-05
# Epoch 14/500
# 3/3 [==============================] - ETA: 0s - loss: 0.5262 - accuracy: 0.8269
# Epoch 14: val_loss improved from 0.69218 to 0.68755, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.5262 - accuracy: 0.8269 - val_loss: 0.6875 - val_accuracy: 0.7181 - lr: 3.0000e-05
# Epoch 15/500
# 3/3 [==============================] - ETA: 0s - loss: 0.5002 - accuracy: 0.8540
# Epoch 15: val_loss improved from 0.68755 to 0.68227, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.5002 - accuracy: 0.8540 - val_loss: 0.6823 - val_accuracy: 0.8357 - lr: 3.0000e-05
# Epoch 16/500
# 3/3 [==============================] - ETA: 0s - loss: 0.4760 - accuracy: 0.8765
# Epoch 16: val_loss improved from 0.68227 to 0.67652, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.4760 - accuracy: 0.8765 - val_loss: 0.6765 - val_accuracy: 0.9415 - lr: 3.0000e-05
# Epoch 17/500
# 3/3 [==============================] - ETA: 0s - loss: 0.4527 - accuracy: 0.8955
# Epoch 17: val_loss improved from 0.67652 to 0.67025, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.4527 - accuracy: 0.8955 - val_loss: 0.6702 - val_accuracy: 0.9500 - lr: 3.0000e-05
# Epoch 18/500
# 3/3 [==============================] - ETA: 0s - loss: 0.4322 - accuracy: 0.9102
# Epoch 18: val_loss improved from 0.67025 to 0.66355, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.4322 - accuracy: 0.9102 - val_loss: 0.6636 - val_accuracy: 0.9474 - lr: 3.0000e-05
# Epoch 19/500
# 3/3 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.9229
# Epoch 19: val_loss improved from 0.66355 to 0.65660, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 6s 3s/step - loss: 0.4132 - accuracy: 0.9229 - val_loss: 0.6566 - val_accuracy: 0.9436 - lr: 3.0000e-05
# Epoch 20/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.9331
# Epoch 20: val_loss improved from 0.65660 to 0.64952, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.3957 - accuracy: 0.9331 - val_loss: 0.6495 - val_accuracy: 0.9416 - lr: 3.0000e-05
# Epoch 21/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3796 - accuracy: 0.9417
# Epoch 21: val_loss improved from 0.64952 to 0.64233, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.3796 - accuracy: 0.9417 - val_loss: 0.6423 - val_accuracy: 0.9392 - lr: 3.0000e-05
# Epoch 22/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3647 - accuracy: 0.9491
# Epoch 22: val_loss improved from 0.64233 to 0.63505, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.3647 - accuracy: 0.9491 - val_loss: 0.6351 - val_accuracy: 0.9382 - lr: 3.0000e-05
# Epoch 23/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3516 - accuracy: 0.9548
# Epoch 23: val_loss improved from 0.63505 to 0.62770, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.3516 - accuracy: 0.9548 - val_loss: 0.6277 - val_accuracy: 0.9386 - lr: 3.0000e-05
# Epoch 24/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3395 - accuracy: 0.9594
# Epoch 24: val_loss improved from 0.62770 to 0.62036, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.3395 - accuracy: 0.9594 - val_loss: 0.6204 - val_accuracy: 0.9386 - lr: 3.0000e-05
# Epoch 25/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.9637
# Epoch 25: val_loss improved from 0.62036 to 0.61296, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 6s 2s/step - loss: 0.3274 - accuracy: 0.9637 - val_loss: 0.6130 - val_accuracy: 0.9382 - lr: 3.0000e-05
# Epoch 26/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.9676
# Epoch 26: val_loss improved from 0.61296 to 0.60557, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.3165 - accuracy: 0.9676 - val_loss: 0.6056 - val_accuracy: 0.9386 - lr: 3.0000e-05
# Epoch 27/500
# 3/3 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.9709
# Epoch 27: val_loss improved from 0.60557 to 0.59827, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.3068 - accuracy: 0.9709 - val_loss: 0.5983 - val_accuracy: 0.9385 - lr: 3.0000e-05
# Epoch 28/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2980 - accuracy: 0.9734
# Epoch 28: val_loss improved from 0.59827 to 0.59105, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 7s 3s/step - loss: 0.2980 - accuracy: 0.9734 - val_loss: 0.5911 - val_accuracy: 0.9389 - lr: 3.0000e-05
# Epoch 29/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2886 - accuracy: 0.9762
# Epoch 29: val_loss improved from 0.59105 to 0.58388, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2886 - accuracy: 0.9762 - val_loss: 0.5839 - val_accuracy: 0.9394 - lr: 3.0000e-05
# Epoch 30/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2809 - accuracy: 0.9781
# Epoch 30: val_loss improved from 0.58388 to 0.57680, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2809 - accuracy: 0.9781 - val_loss: 0.5768 - val_accuracy: 0.9398 - lr: 3.0000e-05
# Epoch 31/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.9800
# Epoch 31: val_loss improved from 0.57680 to 0.56983, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2733 - accuracy: 0.9800 - val_loss: 0.5698 - val_accuracy: 0.9401 - lr: 3.0000e-05
# Epoch 32/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.9811
# Epoch 32: val_loss improved from 0.56983 to 0.56299, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2670 - accuracy: 0.9811 - val_loss: 0.5630 - val_accuracy: 0.9404 - lr: 3.0000e-05
# Epoch 33/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9832
# Epoch 33: val_loss improved from 0.56299 to 0.55629, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.2593 - accuracy: 0.9832 - val_loss: 0.5563 - val_accuracy: 0.9406 - lr: 3.0000e-05
# Epoch 34/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.9828
# Epoch 34: val_loss improved from 0.55629 to 0.54977, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.2563 - accuracy: 0.9828 - val_loss: 0.5498 - val_accuracy: 0.9407 - lr: 3.0000e-05
# Epoch 35/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2488 - accuracy: 0.9848
# Epoch 35: val_loss improved from 0.54977 to 0.54344, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.2488 - accuracy: 0.9848 - val_loss: 0.5434 - val_accuracy: 0.9408 - lr: 3.0000e-05
# Epoch 36/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2438 - accuracy: 0.9858
# Epoch 36: val_loss improved from 0.54344 to 0.53727, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2438 - accuracy: 0.9858 - val_loss: 0.5373 - val_accuracy: 0.9409 - lr: 3.0000e-05
# Epoch 37/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2380 - accuracy: 0.9865
# Epoch 37: val_loss improved from 0.53727 to 0.53123, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2380 - accuracy: 0.9865 - val_loss: 0.5312 - val_accuracy: 0.9410 - lr: 3.0000e-05
# Epoch 38/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2319 - accuracy: 0.9883
# Epoch 38: val_loss improved from 0.53123 to 0.52533, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2319 - accuracy: 0.9883 - val_loss: 0.5253 - val_accuracy: 0.9411 - lr: 3.0000e-05
# Epoch 39/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9879
# Epoch 39: val_loss improved from 0.52533 to 0.51953, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2294 - accuracy: 0.9879 - val_loss: 0.5195 - val_accuracy: 0.9415 - lr: 3.0000e-05
# Epoch 40/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9890
# Epoch 40: val_loss improved from 0.51953 to 0.51381, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.2238 - accuracy: 0.9890 - val_loss: 0.5138 - val_accuracy: 0.9424 - lr: 3.0000e-05
# Epoch 41/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.9897
# Epoch 41: val_loss improved from 0.51381 to 0.50824, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2199 - accuracy: 0.9897 - val_loss: 0.5082 - val_accuracy: 0.9425 - lr: 3.0000e-05
# Epoch 42/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9901
# Epoch 42: val_loss improved from 0.50824 to 0.50279, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2157 - accuracy: 0.9901 - val_loss: 0.5028 - val_accuracy: 0.9426 - lr: 3.0000e-05
# Epoch 43/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2113 - accuracy: 0.9912
# Epoch 43: val_loss improved from 0.50279 to 0.49738, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.2113 - accuracy: 0.9912 - val_loss: 0.4974 - val_accuracy: 0.9426 - lr: 3.0000e-05
# Epoch 44/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9917
# Epoch 44: val_loss improved from 0.49738 to 0.49207, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2081 - accuracy: 0.9917 - val_loss: 0.4921 - val_accuracy: 0.9426 - lr: 3.0000e-05
# Epoch 45/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.9914
# Epoch 45: val_loss improved from 0.49207 to 0.48678, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2056 - accuracy: 0.9914 - val_loss: 0.4868 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 46/500
# 3/3 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9925
# Epoch 46: val_loss improved from 0.48678 to 0.48155, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.2015 - accuracy: 0.9925 - val_loss: 0.4816 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 47/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9929
# Epoch 47: val_loss improved from 0.48155 to 0.47632, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1985 - accuracy: 0.9929 - val_loss: 0.4763 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 48/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1954 - accuracy: 0.9934
# Epoch 48: val_loss improved from 0.47632 to 0.47104, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1954 - accuracy: 0.9934 - val_loss: 0.4710 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 49/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9936
# Epoch 49: val_loss improved from 0.47104 to 0.46571, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1928 - accuracy: 0.9936 - val_loss: 0.4657 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 50/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9941
# Epoch 50: val_loss improved from 0.46571 to 0.46028, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1899 - accuracy: 0.9941 - val_loss: 0.4603 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 51/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9943
# Epoch 51: val_loss improved from 0.46028 to 0.45476, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.1877 - accuracy: 0.9943 - val_loss: 0.4548 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 52/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9941
# Epoch 52: val_loss improved from 0.45476 to 0.44918, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1861 - accuracy: 0.9941 - val_loss: 0.4492 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 53/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1835 - accuracy: 0.9946
# Epoch 53: val_loss improved from 0.44918 to 0.44353, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1835 - accuracy: 0.9946 - val_loss: 0.4435 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 54/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1811 - accuracy: 0.9948
# Epoch 54: val_loss improved from 0.44353 to 0.43788, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1811 - accuracy: 0.9948 - val_loss: 0.4379 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 55/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9951
# Epoch 55: val_loss improved from 0.43788 to 0.43224, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1795 - accuracy: 0.9951 - val_loss: 0.4322 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 56/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1771 - accuracy: 0.9954
# Epoch 56: val_loss improved from 0.43224 to 0.42653, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1771 - accuracy: 0.9954 - val_loss: 0.4265 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 57/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9953
# Epoch 57: val_loss improved from 0.42653 to 0.42075, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1758 - accuracy: 0.9953 - val_loss: 0.4207 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 58/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9955
# Epoch 58: val_loss improved from 0.42075 to 0.41496, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1737 - accuracy: 0.9955 - val_loss: 0.4150 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 59/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9958
# Epoch 59: val_loss improved from 0.41496 to 0.40922, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1720 - accuracy: 0.9958 - val_loss: 0.4092 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 60/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.9959
# Epoch 60: val_loss improved from 0.40922 to 0.40358, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 8s 2s/step - loss: 0.1702 - accuracy: 0.9959 - val_loss: 0.4036 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 61/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9957
# Epoch 61: val_loss improved from 0.40358 to 0.39800, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1693 - accuracy: 0.9957 - val_loss: 0.3980 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 62/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9962
# Epoch 62: val_loss improved from 0.39800 to 0.39249, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1673 - accuracy: 0.9962 - val_loss: 0.3925 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 63/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9962
# Epoch 63: val_loss improved from 0.39249 to 0.38708, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1657 - accuracy: 0.9962 - val_loss: 0.3871 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 64/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9961
# Epoch 64: val_loss improved from 0.38708 to 0.38184, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1645 - accuracy: 0.9961 - val_loss: 0.3818 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 65/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9960
# Epoch 65: val_loss improved from 0.38184 to 0.37664, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1640 - accuracy: 0.9960 - val_loss: 0.3766 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 66/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9963
# Epoch 66: val_loss improved from 0.37664 to 0.37154, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 7s 3s/step - loss: 0.1621 - accuracy: 0.9963 - val_loss: 0.3715 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 67/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9962
# Epoch 67: val_loss improved from 0.37154 to 0.36647, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1613 - accuracy: 0.9962 - val_loss: 0.3665 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 68/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.9963
# Epoch 68: val_loss improved from 0.36647 to 0.36150, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1597 - accuracy: 0.9963 - val_loss: 0.3615 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 69/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9965
# Epoch 69: val_loss improved from 0.36150 to 0.35672, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 6s 2s/step - loss: 0.1585 - accuracy: 0.9965 - val_loss: 0.3567 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 70/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9967
# Epoch 70: val_loss improved from 0.35672 to 0.35199, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1572 - accuracy: 0.9967 - val_loss: 0.3520 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 71/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1560 - accuracy: 0.9967
# Epoch 71: val_loss improved from 0.35199 to 0.34750, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1560 - accuracy: 0.9967 - val_loss: 0.3475 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 72/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9969
# Epoch 72: val_loss improved from 0.34750 to 0.34335, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 6s 3s/step - loss: 0.1550 - accuracy: 0.9969 - val_loss: 0.3433 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 73/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1540 - accuracy: 0.9969
# Epoch 73: val_loss improved from 0.34335 to 0.33936, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 6s 3s/step - loss: 0.1540 - accuracy: 0.9969 - val_loss: 0.3394 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 74/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9971
# Epoch 74: val_loss improved from 0.33936 to 0.33511, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1530 - accuracy: 0.9971 - val_loss: 0.3351 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 75/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1519 - accuracy: 0.9970
# Epoch 75: val_loss improved from 0.33511 to 0.33081, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1519 - accuracy: 0.9970 - val_loss: 0.3308 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 76/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1511 - accuracy: 0.9970
# Epoch 76: val_loss improved from 0.33081 to 0.32689, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1511 - accuracy: 0.9970 - val_loss: 0.3269 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 77/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9970
# Epoch 77: val_loss improved from 0.32689 to 0.32332, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1505 - accuracy: 0.9970 - val_loss: 0.3233 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 78/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9965
# Epoch 78: val_loss improved from 0.32332 to 0.31936, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1506 - accuracy: 0.9965 - val_loss: 0.3194 - val_accuracy: 0.9427 - lr: 3.0000e-05
# Epoch 79/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1497 - accuracy: 0.9965
# Epoch 79: val_loss improved from 0.31936 to 0.31551, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1497 - accuracy: 0.9965 - val_loss: 0.3155 - val_accuracy: 0.9429 - lr: 3.0000e-05
# Epoch 80/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9968
# Epoch 80: val_loss improved from 0.31551 to 0.31136, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1483 - accuracy: 0.9968 - val_loss: 0.3114 - val_accuracy: 0.9434 - lr: 3.0000e-05
# Epoch 81/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9970
# Epoch 81: val_loss improved from 0.31136 to 0.30780, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1472 - accuracy: 0.9970 - val_loss: 0.3078 - val_accuracy: 0.9437 - lr: 3.0000e-05
# Epoch 82/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9971
# Epoch 82: val_loss improved from 0.30780 to 0.30477, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1462 - accuracy: 0.9971 - val_loss: 0.3048 - val_accuracy: 0.9439 - lr: 3.0000e-05
# Epoch 83/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9972
# Epoch 83: val_loss improved from 0.30477 to 0.30194, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1456 - accuracy: 0.9972 - val_loss: 0.3019 - val_accuracy: 0.9440 - lr: 3.0000e-05
# Epoch 84/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9972
# Epoch 84: val_loss improved from 0.30194 to 0.29760, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1448 - accuracy: 0.9972 - val_loss: 0.2976 - val_accuracy: 0.9450 - lr: 3.0000e-05
# Epoch 85/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9969
# Epoch 85: val_loss improved from 0.29760 to 0.29377, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1447 - accuracy: 0.9969 - val_loss: 0.2938 - val_accuracy: 0.9458 - lr: 3.0000e-05
# Epoch 86/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9972
# Epoch 86: val_loss improved from 0.29377 to 0.28951, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1432 - accuracy: 0.9972 - val_loss: 0.2895 - val_accuracy: 0.9468 - lr: 3.0000e-05
# Epoch 87/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1430 - accuracy: 0.9971
# Epoch 87: val_loss improved from 0.28951 to 0.28609, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1430 - accuracy: 0.9971 - val_loss: 0.2861 - val_accuracy: 0.9473 - lr: 3.0000e-05
# Epoch 88/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9972
# Epoch 88: val_loss improved from 0.28609 to 0.28283, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1420 - accuracy: 0.9972 - val_loss: 0.2828 - val_accuracy: 0.9478 - lr: 3.0000e-05
# Epoch 89/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9975
# Epoch 89: val_loss improved from 0.28283 to 0.27888, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1411 - accuracy: 0.9975 - val_loss: 0.2789 - val_accuracy: 0.9486 - lr: 3.0000e-05
# Epoch 90/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9973
# Epoch 90: val_loss improved from 0.27888 to 0.27516, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1405 - accuracy: 0.9973 - val_loss: 0.2752 - val_accuracy: 0.9491 - lr: 3.0000e-05
# Epoch 91/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9974
# Epoch 91: val_loss improved from 0.27516 to 0.27289, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1399 - accuracy: 0.9974 - val_loss: 0.2729 - val_accuracy: 0.9491 - lr: 3.0000e-05
# Epoch 92/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9975
# Epoch 92: val_loss improved from 0.27289 to 0.26908, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1392 - accuracy: 0.9975 - val_loss: 0.2691 - val_accuracy: 0.9496 - lr: 3.0000e-05
# Epoch 93/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9966
# Epoch 93: val_loss improved from 0.26908 to 0.26612, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1403 - accuracy: 0.9966 - val_loss: 0.2661 - val_accuracy: 0.9499 - lr: 3.0000e-05
# Epoch 94/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.9976
# Epoch 94: val_loss improved from 0.26612 to 0.26189, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1380 - accuracy: 0.9976 - val_loss: 0.2619 - val_accuracy: 0.9508 - lr: 3.0000e-05
# Epoch 95/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9975
# Epoch 95: val_loss improved from 0.26189 to 0.25741, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1374 - accuracy: 0.9975 - val_loss: 0.2574 - val_accuracy: 0.9525 - lr: 3.0000e-05
# Epoch 96/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9974
# Epoch 96: val_loss improved from 0.25741 to 0.25289, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1370 - accuracy: 0.9974 - val_loss: 0.2529 - val_accuracy: 0.9548 - lr: 3.0000e-05
# Epoch 97/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1365 - accuracy: 0.9975
# Epoch 97: val_loss improved from 0.25289 to 0.24982, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1365 - accuracy: 0.9975 - val_loss: 0.2498 - val_accuracy: 0.9557 - lr: 3.0000e-05
# Epoch 98/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1360 - accuracy: 0.9975
# Epoch 98: val_loss improved from 0.24982 to 0.24638, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1360 - accuracy: 0.9975 - val_loss: 0.2464 - val_accuracy: 0.9568 - lr: 3.0000e-05
# Epoch 99/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9974
# Epoch 99: val_loss improved from 0.24638 to 0.24207, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1356 - accuracy: 0.9974 - val_loss: 0.2421 - val_accuracy: 0.9583 - lr: 3.0000e-05
# Epoch 100/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9975
# Epoch 100: val_loss improved from 0.24207 to 0.23810, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1349 - accuracy: 0.9975 - val_loss: 0.2381 - val_accuracy: 0.9599 - lr: 3.0000e-05
# Epoch 101/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9974
# Epoch 101: val_loss improved from 0.23810 to 0.23585, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 5s 2s/step - loss: 0.1346 - accuracy: 0.9974 - val_loss: 0.2359 - val_accuracy: 0.9603 - lr: 3.0000e-05
# Epoch 102/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9977
# Epoch 102: val_loss improved from 0.23585 to 0.23341, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 6s 3s/step - loss: 0.1337 - accuracy: 0.9977 - val_loss: 0.2334 - val_accuracy: 0.9610 - lr: 3.0000e-05
# Epoch 103/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1344 - accuracy: 0.9972
# Epoch 103: val_loss improved from 0.23341 to 0.22927, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 1s/step - loss: 0.1344 - accuracy: 0.9972 - val_loss: 0.2293 - val_accuracy: 0.9622 - lr: 3.0000e-05
# Epoch 104/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1329 - accuracy: 0.9976
# Epoch 104: val_loss improved from 0.22927 to 0.22604, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1329 - accuracy: 0.9976 - val_loss: 0.2260 - val_accuracy: 0.9630 - lr: 3.0000e-05
# Epoch 105/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9976
# Epoch 105: val_loss improved from 0.22604 to 0.22091, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1325 - accuracy: 0.9976 - val_loss: 0.2209 - val_accuracy: 0.9653 - lr: 3.0000e-05
# Epoch 106/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9976
# Epoch 106: val_loss did not improve from 0.22091
# 3/3 [==============================] - 2s 694ms/step - loss: 0.1320 - accuracy: 0.9976 - val_loss: 0.2218 - val_accuracy: 0.9640 - lr: 3.0000e-05
# Epoch 107/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9975
# Epoch 107: val_loss improved from 0.22091 to 0.22033, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1320 - accuracy: 0.9975 - val_loss: 0.2203 - val_accuracy: 0.9642 - lr: 3.0000e-05
# Epoch 108/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1312 - accuracy: 0.9976
# Epoch 108: val_loss improved from 0.22033 to 0.21757, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# 3/3 [==============================] - 4s 2s/step - loss: 0.1312 - accuracy: 0.9976 - val_loss: 0.2176 - val_accuracy: 0.9652 - lr: 3.0000e-05
# Epoch 109/500
# 3/3 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9977
# Epoch 109: val_loss improved from 0.21757 to 0.21549, saving model to /content/drive/MyDrive/Colab Notebooks/cell_segmentation_and_classifier/Segmentation_data_and_labels/Segmentation_Data_files/unet-non-aug.h5
# ...
# Epoch 446/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 446: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 699ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-22
# Epoch 447/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 447: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 733ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-22
# Epoch 448/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 448: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 707ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-22
# Epoch 449/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9986
# Epoch 449: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 769ms/step - loss: 0.0943 - accuracy: 0.9986 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-23
# Epoch 450/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9988
# Epoch 450: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 768ms/step - loss: 0.0940 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-23
# Epoch 451/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 451: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 769ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-23
# Epoch 452/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9987
# Epoch 452: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 772ms/step - loss: 0.0940 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-23
# Epoch 453/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 453: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-23
# Epoch 454/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9988
# Epoch 454: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 769ms/step - loss: 0.0938 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-23
# Epoch 455/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 455: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 701ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-23
# Epoch 456/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 456: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 699ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-23
# Epoch 457/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 457: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 701ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-23
# Epoch 458/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 458: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 771ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-23
# Epoch 459/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9974
# Epoch 459: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0994 - accuracy: 0.9974 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 460/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 460: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 771ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 461/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 461: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 713ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 462/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 462: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 767ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 463/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 463: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 715ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 464/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 464: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 705ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 465/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 465: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 786ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-24
# Epoch 466/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 466: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 766ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 467/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9988
# Epoch 467: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 769ms/step - loss: 0.0938 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 468/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 468: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 702ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-24
# Epoch 469/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0950 - accuracy: 0.9984
# Epoch 469: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 772ms/step - loss: 0.0950 - accuracy: 0.9984 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 470/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 470: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 731ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 471/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 471: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 704ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 472/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 472: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 768ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 473/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 473: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 707ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 474/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 474: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 710ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 475/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9988
# Epoch 475: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 773ms/step - loss: 0.0940 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 476/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 476: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 777ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 477/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 477: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 702ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 478/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 478: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 705ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-25
# Epoch 479/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9988
# Epoch 479: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 772ms/step - loss: 0.0938 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 480/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9984
# Epoch 480: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 773ms/step - loss: 0.0946 - accuracy: 0.9984 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 481/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 481: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 702ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-26
# Epoch 482/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 482: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 723ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 483/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9988
# Epoch 483: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 702ms/step - loss: 0.0938 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 484/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9984
# Epoch 484: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 707ms/step - loss: 0.0946 - accuracy: 0.9984 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 485/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 485: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 708ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 486/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9988
# Epoch 486: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 710ms/step - loss: 0.0938 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 487/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9989
# Epoch 487: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 720ms/step - loss: 0.0938 - accuracy: 0.9989 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 488/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9987
# Epoch 488: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 704ms/step - loss: 0.0938 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-26
# Epoch 489/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 489: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 703ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-27
# Epoch 490/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 490: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 700ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-27
# Epoch 491/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 491: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 769ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-27
# Epoch 492/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 492: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 767ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-27
# Epoch 493/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 493: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 719ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-27
# Epoch 494/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9984
# Epoch 494: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 700ms/step - loss: 0.0953 - accuracy: 0.9984 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-27
# Epoch 495/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 495: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 711ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-27
# Epoch 496/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 0.9988
# Epoch 496: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 719ms/step - loss: 0.0938 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-27
# Epoch 497/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9987
# Epoch 497: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 767ms/step - loss: 0.0939 - accuracy: 0.9987 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-27
# Epoch 498/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 498: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 784ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0924 - val_accuracy: 0.9907 - lr: 3.0000e-27
# Epoch 499/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0939 - accuracy: 0.9988
# Epoch 499: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 795ms/step - loss: 0.0939 - accuracy: 0.9988 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-28
# Epoch 500/500
# 3/3 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9983
# Epoch 500: val_loss did not improve from 0.08939
# 3/3 [==============================] - 2s 768ms/step - loss: 0.0948 - accuracy: 0.9983 - val_loss: 0.0913 - val_accuracy: 0.9914 - lr: 3.0000e-28
